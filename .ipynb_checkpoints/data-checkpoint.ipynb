# %%
import pandas as pd

# %%
df = pd.read_csv('WorldWide_Boxoffice.csv')

# %%
df
# Out:
#      Rank  Year                                 Movie WorldwideBox Office  \
# 0       1  2009                                Avatar      $2,845,899,541
# 1       2  2019                     Avengers: Endgame      $2,797,800,564
# 2       3  1997                               Titanic      $2,207,986,545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens      $2,064,615,817
# 4       5  2018                Avengers: Infinity War      $2,044,540,523
# ..    ...   ...                                   ...                 ...
# 590   596  2010                        Knight and Day        $258,751,370
# 591   597  1985                         Out of Africa        $258,210,860
# 592   598  2011                               Super 8        $257,972,745
# 593   599  2013                       American Hustle        $257,858,943
# 594   600  2000                       Erin Brockovich        $257,805,243
#
#     DomesticBox Office InternationalBox Office
# ...

# %% [markdown]
# ### Checking data Type

# %%
print(df.dtypes)
# Out:
# Rank                        int64
# Year                        int64
# Movie                      object
# WorldwideBox Office        object
# DomesticBox Office         object
# InternationalBox Office    object
# dtype: object

# %% [markdown]
# ### Box office parsing into integers

# %%
df['WorldwideBox Office'] = df['WorldwideBox Office'].astype(str)
df['DomesticBox Office'] = df['DomesticBox Office'].astype(str)
df['InternationalBox Office'] = df['InternationalBox Office'].astype(str)


print(df.dtypes)
# Out:
# Rank                        int64
# Year                        int64
# Movie                      object
# WorldwideBox Office        object
# DomesticBox Office         object
# InternationalBox Office    object
# dtype: object

# %%
df['WorldwideBox Office'] = df['WorldwideBox Office'].apply(lambda x: x.replace(',','').replace('$',''))
df['DomesticBox Office'] = df['DomesticBox Office'].apply(lambda x: x.replace(',','').replace('$',''))
df['InternationalBox Office'] = df['InternationalBox Office'].apply(lambda x: x.replace(',','').replace('$',''))

# %%
df
# Out:
#      Rank  Year                                 Movie WorldwideBox Office  \
# 0       1  2009                                Avatar          2845899541
# 1       2  2019                     Avengers: Endgame          2797800564
# 2       3  1997                               Titanic          2207986545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens          2064615817
# 4       5  2018                Avengers: Infinity War          2044540523
# ..    ...   ...                                   ...                 ...
# 590   596  2010                        Knight and Day           258751370
# 591   597  1985                         Out of Africa           258210860
# 592   598  2011                               Super 8           257972745
# 593   599  2013                       American Hustle           257858943
# 594   600  2000                       Erin Brockovich           257805243
#
#     DomesticBox Office InternationalBox Office
# ...

# %% [markdown]
# ### adding one new data

# %%
df.iloc[6]=['6','2021','Spider-Man: No Way Home','1850476678','780418859','1070057819']

# %%
df.loc[df['Movie'] == 'Spider-Man: No Way Home']
# Out:
#   Rank  Year                    Movie WorldwideBox Office DomesticBox Office  \
# 6    6  2021  Spider-Man: No Way Home          1850476678          780418859
#
#   InternationalBox Office
# 6              1070057819

# %%
df
# Out:
#     Rank  Year                                 Movie WorldwideBox Office  \
# 0      1  2009                                Avatar          2845899541
# 1      2  2019                     Avengers: Endgame          2797800564
# 2      3  1997                               Titanic          2207986545
# 3      4  2015  Star Wars Ep. VII: The Force Awakens          2064615817
# 4      5  2018                Avengers: Infinity War          2044540523
# ..   ...   ...                                   ...                 ...
# 590  596  2010                        Knight and Day           258751370
# 591  597  1985                         Out of Africa           258210860
# 592  598  2011                               Super 8           257972745
# 593  599  2013                       American Hustle           257858943
# 594  600  2000                       Erin Brockovich           257805243
#
#     DomesticBox Office InternationalBox Office
# ...

# %%
df
# Out:
#     Rank  Year                                 Movie WorldwideBox Office  \
# 0      1  2009                                Avatar          2845899541
# 1      2  2019                     Avengers: Endgame          2797800564
# 2      3  1997                               Titanic          2207986545
# 3      4  2015  Star Wars Ep. VII: The Force Awakens          2064615817
# 4      5  2018                Avengers: Infinity War          2044540523
# ..   ...   ...                                   ...                 ...
# 590  596  2010                        Knight and Day           258751370
# 591  597  1985                         Out of Africa           258210860
# 592  598  2011                               Super 8           257972745
# 593  599  2013                       American Hustle           257858943
# 594  600  2000                       Erin Brockovich           257805243
#
#     DomesticBox Office InternationalBox Office
# ...

# %% [markdown]
#  ##  Replacing Null values With Average      Values

# %%
df = df.fillna(value=df["DomesticBox Office"].mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1605             try:
# -> 1606                 x = complex(x)
#    1607             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df.isnull().sum()
# Out:
# Rank                       0
# Year                       0
# Movie                      0
# WorldwideBox Office        0
# DomesticBox Office         0
# InternationalBox Office    0
# dtype: int64

# %%
df
# Out:
#     Rank  Year                                 Movie WorldwideBox Office  \
# 0      1  2009                                Avatar          2845899541
# 1      2  2019                     Avengers: Endgame          2797800564
# 2      3  1997                               Titanic          2207986545
# 3      4  2015  Star Wars Ep. VII: The Force Awakens          2064615817
# 4      5  2018                Avengers: Infinity War          2044540523
# ..   ...   ...                                   ...                 ...
# 590  596  2010                        Knight and Day           258751370
# 591  597  1985                         Out of Africa           258210860
# 592  598  2011                               Super 8           257972745
# 593  599  2013                       American Hustle           257858943
# 594  600  2000                       Erin Brockovich           257805243
#
#     DomesticBox Office InternationalBox Office
# ...

# %%
df.drop(['Unnamed: 0'],axis=1)
# Out:
#      Rank  Year                                 Movie  WorldwideBox Office  \
# 0       1  2009                                Avatar           2845899541
# 1       2  2019                     Avengers: Endgame           2797800564
# 2       3  1997                               Titanic           2207986545
# 3       4  2015  Star Wars Ep. VII: The Force Awakens           2064615817
# 4       5  2018                Avengers: Infinity War           2044540523
# ..    ...   ...                                   ...                  ...
# 590   596  2010                        Knight and Day            258751370
# 591   597  1985                         Out of Africa            258210860
# 592   598  2011                               Super 8            257972745
# 593   599  2013                       American Hustle            257858943
# 594   600  2000                       Erin Brockovich            257805243
#
#      DomesticBox Office  InternationalBox Office
# ...

# %%
df.to_csv('Modified_data.csv')
